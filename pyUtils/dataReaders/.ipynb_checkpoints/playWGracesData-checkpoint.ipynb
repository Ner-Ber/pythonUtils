# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'


# %matplotlib widget
# %reload_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('.')
import readGracesData
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
from importlib import reload
import MyGeneral
import MyMapping
from copy import deepcopy
import pygmt
import pandas as pd
from matplotlib.widgets import Slider, Button

# %%
reload(readGracesData)
folderPath = Path('H:\My Drive\icequakes\gps_data')
fileName = 'WIS10'
filePath = folderPath / fileName
data10 = readGracesData.readGracesGeodeticData(filePath)[fileName]
# Out:
# <module 'readGracesData' from 'g:\\My Drive\\pythonCode\\dataReaders\\readGracesData.py'>
# t: 		 type <class 'numpy.ndarray'> 	  size 112 	 shape (287918, 1)
# data: 		 type <class 'numpy.ndarray'> 	  size 112 	 shape (287918, 35)
# st: 		 type <class 'numpy.ndarray'> 	  size 112 	 shape (77, 1)
# st_ind: 		 type <class 'numpy.ndarray'> 	  size 112 	 shape (77, 1)
# x: 		 type <class 'numpy.ndarray'> 	  size 112 	 shape (35, 1)
# y: 		 type <class 'numpy.ndarray'> 	  size 112 	 shape (35, 1)

# %%
reload(readGracesData)
folderPath = Path('H:\My Drive\icequakes\gps_data')
fileName = 'WIS11'
filePath = folderPath / fileName
data = readGracesData.readGracesGeodeticData(filePath)[fileName]
# Out:
# <module 'readGracesData' from 'g:\\My Drive\\pythonCode\\dataReaders\\readGracesData.py'>
# t: 		 type <class 'numpy.ndarray'> 	  size 112 	 shape (1, 126721)
# x: 		 type <class 'numpy.ndarray'> 	  size 112 	 shape (18, 1)
# y: 		 type <class 'numpy.ndarray'> 	  size 112 	 shape (18, 1)
# e: 		 type <class 'numpy.ndarray'> 	  size 112 	 shape (126721, 18)
# n: 		 type <class 'numpy.ndarray'> 	  size 112 	 shape (126721, 18)
# z: 		 type <class 'numpy.ndarray'> 	  size 112 	 shape (126721, 18)
# d: 		 type <class 'numpy.ndarray'> 	  size 112 	 shape (126721, 18)
# slipst: 		 type <class 'numpy.ndarray'> 	  size 112 	 shape (1, 32)
# slipst_ind: 		 type <class 'numpy.ndarray'> 	  size 112 	 shape (1, 32)
# tideh: 		 type <class 'numpy.ndarray'> 	  size 112 	 shape (1, 126721)

# %% [markdown]
# #### cute - tide and station height

# %%
fig, ax1 = plt.subplots()
ax2 = ax1.twinx()
ax1.plot(data['z'].T[0])
ax2.plot(data['tideh'].ravel(),'g')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.figure()
plt.plot(data10['t'].ravel(), data10['data']);
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.figure()
plt.plot(data['t'].ravel(), data['d']);
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## derivative of previous plot to see velocities

# %%
data['d'].shape
# Out:
# (126721, 18)

# %%
avgKernel = np.array([0.5, 0.5])
time4vel = np.convolve(data['t'].ravel(), avgKernel,  mode='valid')
vel = np.diff(data['d'], axis=0)

# %%
plt.figure()
plt.plot(time4vel, vel);
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## plot and show on map

# %%
MyGeneral.whosDict(data)
# Out:
# t: 		 type <class 'numpy.ndarray'> 	  size 112 	 shape (1, 126721)
# x: 		 type <class 'numpy.ndarray'> 	  size 112 	 shape (18, 1)
# y: 		 type <class 'numpy.ndarray'> 	  size 112 	 shape (18, 1)
# e: 		 type <class 'numpy.ndarray'> 	  size 112 	 shape (126721, 18)
# n: 		 type <class 'numpy.ndarray'> 	  size 112 	 shape (126721, 18)
# z: 		 type <class 'numpy.ndarray'> 	  size 112 	 shape (126721, 18)
# d: 		 type <class 'numpy.ndarray'> 	  size 112 	 shape (126721, 18)
# slipst: 		 type <class 'numpy.ndarray'> 	  size 112 	 shape (1, 32)
# slipst_ind: 		 type <class 'numpy.ndarray'> 	  size 112 	 shape (1, 32)
# tideh: 		 type <class 'numpy.ndarray'> 	  size 112 	 shape (1, 126721)

# %%
whatIsThis = np.sqrt(data['e']**2 + data['n']**2)

# %%
fig, ax1 = plt.subplots()
ax2 = ax1.twinx()
ax1.plot(time4vel, vel.T[0])
ax2.plot(data['t'].ravel(), data['tideh'].ravel(),'g')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.figure();
plt.scatter(data['x'], data['y'])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.figure();
plt.scatter(data['n'], data['e'])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.figure();
plt.hist(data['z'].ravel());
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.figure();
plt.scatter(data['n'][0], data['e'][0])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.all(~np.isnan(data['n']), axis=0)
# Out:
# array([ True,  True, False, False, False, False, False,  True, False,
#         True, False,  True, False, False, False, False, False, False])

# %%
np.shape(data['n'].T[0])
# Out:
# (126721,)

# %%
def reduceFirstFinitePoint(inputArray):
    arrayReduced = deepcopy(inputArray)
    for row in arrayReduced:
        row -= row[np.where(np.isfinite(row))[0][0]]
    return arrayReduced

# %%
def plotPointsReduced(inputArray):
    n_reduced = reduceFirstFinitePoint(inputArray.T)
    plt.figure()
    for n in n_reduced:
        plt.plot(n)

# %%
n_reduced = reduceFirstFinitePoint(data['n'].T)

# %%
plotPointsReduced(data['n'])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plotPointsReduced(data['e'])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plotPointsReduced(data['z'])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
z_reduced = reduceFirstFinitePoint(data['z'].T)

# %%
N = 3
np.unique(z_reduced[N][~np.isnan(z_reduced[N])])
# Out:
# array([-0.93409993, -0.93399993, -0.93389993, ...,  0.93330009,
#         0.94779968,  0.94860006])

# %%
N=0
plt.figure()
plt.hist(data['x'].T[N])
# Out:
# (array([1., 1., 2., 2., 2., 3., 2., 2., 2., 1.]),
#  array([-265.669 , -257.1265, -248.584 , -240.0415, -231.499 , -222.9565,
#         -214.414 , -205.8715, -197.329 , -188.7865, -180.244 ]),
#  <BarContainer object of 10 artists>)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
N=0
plt.figure()
plt.hist(data['y'].T[N])
# Out:
# (array([1., 2., 1., 1., 2., 1., 2., 2., 4., 2.]),
#  array([-640.127 , -630.0306, -619.9342, -609.8378, -599.7414, -589.645 ,
#         -579.5486, -569.4522, -559.3558, -549.2594, -539.163 ]),
#  <BarContainer object of 10 artists>)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.figure()
plt.plot(data['x'])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.figure()
plt.plot(data['y'])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
print(data['x'][0])
print(data['y'][0])
# Out:
# [-265.669]
# [-577.157]

# %%
lat_x, lon_y = MyMapping.ps2ll(data['x'], data['y'])
lat_n, lon_e = MyMapping.ps2ll(data['e'], data['n'])
# Out:
# G://My Drive//pythonCode\MyMapping.py:144: RuntimeWarning: invalid value encountered in remainder
#   lon=np.mod(lon+np.pi,2*np.pi)-np.pi; #want longitude in the range -pi to pi

# %%
lat_n.shape
# Out:
# (126721, 18)

# %%
np.nanmax(lat_n.ravel())
np.nanmin(lat_n.ravel())
np.nanmax(lon_e.ravel())
np.nanmin(lon_e.ravel())
# Out:
# -87.29848292268028
# -90.0
# 97.83359726817392
# 0.0

# %%
f, ax = plt.subplots(1,1)
for xx,yy in zip(lat_n.T, lon_e.T):
    ax.plot(xx,yy);
ax.set_xlim(-88.03, -87.02)
ax.set_ylim(73.8, 98.8)
# Out:
# (-88.03, -87.02)
# (73.8, 98.8)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
discreteVel_n = np.diff(lat_n, axis=0)
discreteVel_e = np.diff(lon_e, axis=0)
velMag = np.sqrt(discreteVel_n**2 + discreteVel_e**2 )

# %%
#--- normalize velMag
# velMag -= np.nanmin(velMag.ravel())
velMag /= np.nanmax(velMag.ravel())
# velMag *= 2
# velMag -= 1

# %%
plt.figure()
plt.hist(velMag[~np.isnan(velMag)], 1000)
# Out:
# (array([7.93637e+05, 2.41726e+05, 2.07546e+05, 1.78680e+05, 1.35475e+05,
#         9.42570e+04, 6.72870e+04, 4.57050e+04, 3.06000e+04, 2.06830e+04,
#         1.41550e+04, 9.87200e+03, 7.66900e+03, 6.12300e+03, 4.73100e+03,
#         4.20200e+03, 3.36700e+03, 2.87100e+03, 2.49900e+03, 2.07100e+03,
#         1.91200e+03, 1.64600e+03, 1.43100e+03, 1.19800e+03, 1.05500e+03,
#         9.83000e+02, 7.83000e+02, 6.98000e+02, 6.42000e+02, 5.35000e+02,
#         4.50000e+02, 4.12000e+02, 3.62000e+02, 3.02000e+02, 3.02000e+02,
#         2.46000e+02, 2.44000e+02, 1.96000e+02, 1.80000e+02, 1.66000e+02,
#         1.68000e+02, 1.42000e+02, 1.36000e+02, 1.45000e+02, 1.08000e+02,
#         1.02000e+02, 1.03000e+02, 7.80000e+01, 7.50000e+01, 6.90000e+01,
#         6.90000e+01, 7.40000e+01, 7.40000e+01, 7.80000e+01, 6.70000e+01,
#         7.00000e+01, 4.30000e+01, 4.70000e+01, 3.80000e+01, 4.10000e+01,
#         4.90000e+01, 4.30000e+01, 2.90000e+01, 3.00000e+01, 3.00000e+01,
# ...

# %%
discreteVel_e = np.vstack((np.zeros((1,discreteVel_e.shape[-1])), discreteVel_e))
discreteVel_n = np.vstack((np.zeros((1,discreteVel_n.shape[-1])), discreteVel_n))

# %%
lat_n[T].shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_30440/43793458.py in <module>
# ----> 1 lat_n[T].shape
#
# NameError: name 'T' is not defined

# %%
useGPS = ~np.all(np.isnan(lon_e) | (lon_e==0), axis=0)

# %%
frac = 0.95
T = int(np.round(frac*lat_n.shape[0]))

# %%
plt.figure()
plt.quiver(lat_n[T,useGPS], lon_e[T,useGPS], discreteVel_n[T,useGPS], discreteVel_e[T,useGPS])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib notebook

# %%
T0 = 0

# Create the figure and the line that we will manipulate
fig, ax = plt.subplots()
quiver = plt.quiver(lat_n[T0,useGPS], lon_e[T0,useGPS], discreteVel_n[T0,useGPS], discreteVel_e[T0,useGPS])

# adjust the main plot to make room for the sliders
plt.subplots_adjust(left=0.25, bottom=0.25)

# Make a horizontal slider to control the frequency.
axfreq = plt.axes([0.25, 0.1, 0.65, 0.03])
time_slider = Slider(
    ax=axfreq,
    label='Time',
    valmin=0,
    valmax=(lat_n.shape[0]-1),
    valinit=T0,
)

# The function to be called anytime a slider's value changes
def update(val):
    quiver.set_UVC(discreteVel_n[T0,useGPS], discreteVel_e[T0,useGPS])
    fig.canvas.draw_idle()


# register the update function with each slider
time_slider.on_changed(update)

# Create a `matplotlib.widgets.Button` to reset the sliders to initial values.
resetax = plt.axes([0.8, 0.025, 0.1, 0.04])
button = Button(resetax, 'Reset', hovercolor='0.975')


def reset(event):
    time_slider.reset()
button.on_clicked(reset)

plt.show()
# Out:
# 0
# 0
# c:\Users\NB\pyenvs\generalEnv_2\lib\site-packages\matplotlib\quiver.py:679: RuntimeWarning: divide by zero encountered in double_scalars
#   length = a * (widthu_per_lenu / (self.scale * self.width))
# c:\Users\NB\pyenvs\generalEnv_2\lib\site-packages\matplotlib\quiver.py:679: RuntimeWarning: invalid value encountered in multiply
#   length = a * (widthu_per_lenu / (self.scale * self.width))
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
